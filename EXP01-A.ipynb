# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

# -----------------------------
# Load MNIST Dataset
# -----------------------------
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Normalize pixel values
X_train = X_train / 255.0
X_test = X_test / 255.0

# Flatten 28x28 images into 784 features
X_train = X_train.reshape(-1, 784)
X_test = X_test.reshape(-1, 784)

# One-hot encode labels
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# -----------------------------
# Model Definition (10 Layers)
# -----------------------------
model = Sequential()

# Input Layer (Layer 1)
model.add(Dense(
    128,
    activation='relu',
    kernel_initializer='he_normal',
    input_shape=(784,)
))

# Hidden Layers (Layers 2–9)
model.add(Dense(128, activation='relu', kernel_initializer='he_normal'))  # 2
model.add(Dense(128, activation='relu', kernel_initializer='he_normal'))  # 3
model.add(Dense(64, activation='relu', kernel_initializer='he_normal'))   # 4
model.add(Dense(64, activation='relu', kernel_initializer='he_normal'))   # 5
model.add(Dense(64, activation='relu', kernel_initializer='he_normal'))   # 6
model.add(Dense(32, activation='relu', kernel_initializer='he_normal'))   # 7
model.add(Dense(32, activation='relu', kernel_initializer='he_normal'))   # 8
model.add(Dense(16, activation='relu', kernel_initializer='he_normal'))   # 9

# Output Layer (Layer 10)
model.add(Dense(
    10,
    activation='softmax',
    kernel_initializer='glorot_uniform'
))

# -----------------------------
# Compile Model
# -----------------------------
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()

# -----------------------------
# Train Model
# -----------------------------
history = model.fit(
    X_train,
    y_train,
    epochs=20,
    batch_size=32,
    validation_data=(X_test, y_test),
    verbose=1
)

# -----------------------------
# Evaluate Model
# -----------------------------
test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f"\nTest Accuracy: {test_accuracy:.4f}")

# -----------------------------
# Visualization Graphs
# -----------------------------

# Training & Validation Loss
plt.figure()
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss vs Epochs (He Initialization)')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Training & Validation Accuracy
plt.figure()
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy vs Epochs (He Initialization)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_50 (Dense)                │ (None, 128)            │         2,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_51 (Dense)                │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_52 (Dense)                │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_53 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_54 (Dense)                │ (None, 64)             │         4,160 │
# ...

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.initializers import RandomNormal

# -----------------------------
# Random Initialization
# -----------------------------
random_init = RandomNormal(mean=0.0, stddev=0.05)

# -----------------------------
# Model Definition (UNCHANGED)
# -----------------------------
model = Sequential()

# Input layer
model.add(Dense(
    128,
    activation='relu',
    kernel_initializer=random_init,
    input_shape=(20,)
))

# Hidden layers
model.add(Dense(128, activation='relu', kernel_initializer=random_init))
model.add(Dense(128, activation='relu', kernel_initializer=random_init))
model.add(Dense(64, activation='relu', kernel_initializer=random_init))
model.add(Dense(64, activation='relu', kernel_initializer=random_init))
model.add(Dense(64, activation='relu', kernel_initializer=random_init))
model.add(Dense(32, activation='relu', kernel_initializer=random_init))
model.add(Dense(32, activation='relu', kernel_initializer=random_init))
model.add(Dense(16, activation='relu', kernel_initializer=random_init))

# Output layer
model.add(Dense(
    1,
    activation='sigmoid',
    kernel_initializer=random_init
))

# -----------------------------
# Compile Model (UNCHANGED)
# -----------------------------
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model.summary()

# -----------------------------
# MNIST Dataset (Adjusted ONLY)
# -----------------------------
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()

# Flatten MNIST images
X_train = X_train.reshape(-1, 784)
X_test = X_test.reshape(-1, 784)

# Take only first 20 features to match model input
X_train = X_train[:, :20]
X_test = X_test[:, :20]

# Normalize
X_train = X_train / 255.0
X_test = X_test / 255.0

# Convert labels to binary (0 vs non-0)
y_train = (y_train > 0).astype(int)
y_test = (y_test > 0).astype(int)

# -----------------------------
# Train Model
# -----------------------------
history = model.fit(
    X_train,
    y_train,
    epochs=20,
    batch_size=32,
    verbose=1
)

# -----------------------------
# Visualization (UNCHANGED)
# -----------------------------

# Loss Graph
plt.figure()
plt.plot(history.history['loss'])
plt.title('Training Loss (Random Initializer)')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# Accuracy Graph
plt.figure()
plt.plot(history.history['accuracy'])
plt.title('Training Accuracy (Random Initializer)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.show()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_30 (Dense)                │ (None, 128)            │         2,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_31 (Dense)                │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_32 (Dense)                │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_33 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_34 (Dense)                │ (None, 64)             │         4,160 │
# ...

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.initializers import GlorotUniform

# -----------------------------
# Xavier Initializer
# -----------------------------
xavier_init = GlorotUniform()

# -----------------------------
# Model Definition (UNCHANGED)
# -----------------------------
model = Sequential()

# Input layer (Layer 1)
model.add(Dense(
    128,
    activation='relu',
    kernel_initializer=xavier_init,
    input_shape=(20,)
))

# Hidden layers (Layers 2–9)
model.add(Dense(128, activation='relu', kernel_initializer=xavier_init))  # 2
model.add(Dense(128, activation='relu', kernel_initializer=xavier_init))  # 3
model.add(Dense(64, activation='relu', kernel_initializer=xavier_init))   # 4
model.add(Dense(64, activation='relu', kernel_initializer=xavier_init))   # 5
model.add(Dense(64, activation='relu', kernel_initializer=xavier_init))   # 6
model.add(Dense(32, activation='relu', kernel_initializer=xavier_init))   # 7
model.add(Dense(32, activation='relu', kernel_initializer=xavier_init))   # 8
model.add(Dense(16, activation='relu', kernel_initializer=xavier_init))   # 9

# Output layer (Layer 10)
model.add(Dense(
    1,
    activation='sigmoid',
    kernel_initializer=xavier_init
))

# -----------------------------
# Compile Model (UNCHANGED)
# -----------------------------
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model.summary()

# -----------------------------
# MNIST Dataset (ONLY CHANGE)
# -----------------------------
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()

# Flatten images
X_train = X_train.reshape(-1, 784)
X_test = X_test.reshape(-1, 784)

# Take first 20 features to match input shape
X_train = X_train[:, :20]
X_test = X_test[:, :20]

# Normalize
X_train = X_train / 255.0
X_test = X_test / 255.0

# Convert labels to binary (0 vs non-zero)
y_train = (y_train > 0).astype(int)
y_test = (y_test > 0).astype(int)

# -----------------------------
# Train Model (UNCHANGED)
# -----------------------------
history = model.fit(
    X_train,
    y_train,
    epochs=20,
    batch_size=32,
    verbose=1
)

# -----------------------------
# Visualization Graphs (UNCHANGED)
# -----------------------------

# Loss Graph
plt.figure()
plt.plot(history.history['loss'])
plt.title('Training Loss (Xavier Initialization)')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# Accuracy Graph
plt.figure()
plt.plot(history.history['accuracy'])
plt.title('Training Accuracy (Xavier Initialization)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.show()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_40 (Dense)                │ (None, 128)            │         2,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_41 (Dense)                │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_42 (Dense)                │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_43 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_44 (Dense)                │ (None, 64)             │         4,160 │
# ...
